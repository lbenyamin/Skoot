# %% [markdown]
# # Description KPI
#
# ## Standard
#
# Team
#
# Player
#
# Nation
#
# Position
#
# Age
#
# Born
#
# Match played
#
# Starting player
#
# avg playing time per game
#
# Total goals
#
# Total Assists
#
# Goals&Assists
#
# Goals-penaly
#
# Penalty made
#
# Penalty attempted
#
# Yellow card
#
# Red card
#
# Expected goal without penalty
#
# Expected assists goal
#
# Progressive ball carrie
#
# Progressive passes
#
# Progressive passes received
#
# Goal per 90min
#
# Assists per 90min
#
# Expected assists
#
# Expected assists per 90min
#
# Expected goal per90 without penalty
#
# League
#
# Saison
#
# ## Goalkeeping
#
# Goal conceded
#
# Goal conceded per 90min
#
# Shot on target conceded
#
# Saves
#
# Save percentage
#
# Win
#
# Draw
#
# Loose
#
# No-goal game allowed
#
# No-goal game allowed percentage
#
# Penalty Kick attempted against
#
# Penalty allowed
#
# Penalty saved
#
# Penalty missed
#
# Save percentage on penalty
#
# ## Passing
#
# Total pass completion percentage
#
# Short pass completion percentage
#
# Medium pass completion percentage
#
# Long pass completion percentage
#
# Key passes
#
# Pass into penalty area
#
# Cross into penalty area
#
# ## shooting
#
# Total shots
#
# Shots on target
#
# Shots on target percentage
#
# Shots per 90min
#
# Shots on target per 90min
#
# Goals per shot
#
# Goal per shot on target
#
# Avg shot distance
#
# ## Defense
#
# Total tackles
#
# Tackles won
#
# Dribblers tackled challenge percentage
#
# Number of time blocking the ball
#
# Shots blocked
#
# Passes blocked
#
# Interception
#
# Clearances
#
# Mistake leading to opponent shot
