# %% [markdown]
# # Preprocessing Whoscored

# %% [markdown]
# ## Importation

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df_offensive = pd.read_csv('Offensive_Whoscored_Data.csv')
df_passing = pd.read_csv('Passing_Whoscored_Data.csv')
df_summary = pd.read_csv('Summary_Whoscored_Data.csv')
df_defensive = pd.read_csv('Defensive_Whoscored_Data.csv')

# %%
df_defensive
# Out:
#                  Name           Team  Age    Position   Apps  Minutes  \
# 0        Riyad Mahrez      Leicester   28     AM(CLR)  36(1)     3058
# 1       Dimitri Payet       West Ham   32      M(CLR)  29(1)     2573
# 2      Alexis Sánchez        Arsenal   30   M(CLR),FW  28(2)     2446
# 3       Mousa Dembélé      Tottenham   31       M(CR)  27(2)     2273
# 4          Mesut Özil        Arsenal   30      M(CLR)     35     3049
# ...               ...            ...  ...         ...    ...      ...
# 31794     Hrvoje Cale      Wolfsburg   34    Defender   0(1)       29
# 31795  Marco Djuricin  Hertha Berlin   26          FW   0(2)       39
# 31796       Dawda Bah       Augsburg   35  Midfielder   0(1)       16
# 31797     Daniel Batz       Freiburg   28  Goalkeeper      1       90
# 31798   Sandro Wieser     Hoffenheim   26        D(C)   0(1)       32
#
#       Tackles per game Interceptions per game Fouls per game  \
# 0                  1.4                      1            0.5
# 1                  0.8                    0.8            0.4
# 2                  1.6                    0.8            1.1
# 3                  3.6                    1.9            1.7
# 4                    1                    0.6            0.6
# ...                ...                    ...            ...
# 31794                1                      -              1
# 31795              0.5                    0.5            1.5
# 31796                -                      -              -
# 31797                -                      -              -
# 31798                -                      -              -
#
#       Offsides per game Clearances per game Dribbled past per game  \
# 0                     -                 0.4                    1.9
# 1                     -                 0.1                    0.8
# 2                     -                 0.2                    0.8
# 3                     -                 1.1                    0.4
# 4                     -                 0.3                    1.2
# ...                 ...                 ...                    ...
# 31794                 -                   2                      -
# 31795                 -                   -                      -
# 31796                 -                   -                      3
# 31797                 -                   -                      1
# 31798                 -                   -                      -
#
#       Outfield blocks per game Own goals  Rating         League  Saison
# 0                          0.1         -    7.84  PremierLeague    2015
# 1                            -         -    7.74  PremierLeague    2015
# 2                          0.1         -    7.72  PremierLeague    2015
# 3                          0.3         -    7.69  PremierLeague    2015
# 4                            -         -    7.66  PremierLeague    2015
# ...                        ...       ...     ...            ...     ...
# 31794                        -         -    5.72     Bundesliga    2011
# 31795                        -         -    5.70     Bundesliga    2011
# 31796                        -         -    5.64     Bundesliga    2011
# 31797                        -         -    5.25     Bundesliga    2011
# 31798                        -         -    5.12     Bundesliga    2011
#
# [31799 rows x 17 columns]

# %% [markdown]
# ## Modification Position & Apps

# %% [markdown]
# ### Position

# %%
df_dmc = df_offensive.loc[df_offensive["Position"] == "DMC"]
print(df_dmc)
# Out:
#                         Name                 Team  Age Position   Apps  \
# 333         Christoph Kramer  Borussia M.Gladbach   28      DMC  28(2)
# 372    Julian Baumgartlinger             Mainz 05   31      DMC     26
# 471                Serey Dié        VfB Stuttgart   34      DMC  12(1)
# 494             Dominik Kohr             Augsburg   25      DMC  19(7)
# 549              Oriol Romeu        VfB Stuttgart   27      DMC  20(7)
# ...                      ...                  ...  ...      ...    ...
# 31353        Alhassan Wakaso              Lorient   27      DMC   8(5)
# 31355               Jessy Pi             Toulouse   25      DMC  3(13)
# 31385        Abdoulaye Touré               Nantes   25      DMC   3(9)
# 31387        Mauro Arambarri             Bordeaux   23      DMC   0(4)
# 31456           Didier Ndong              Lorient   25      DMC      2
#
#       Minutes Total goals Total Assists Shots per game Key passes per game  \
# 333      2508           2             1            0.4                 0.8
# 372      2307           -             -            0.6                 0.6
# 471       981           -             2            0.7                 0.5
# 494      1640           1             1            0.7                 0.4
# 549      1824           -             -            0.4                 0.2
# ...       ...         ...           ...            ...                 ...
# 31353     684           -             -              1                 0.2
# 31355     421           -             1            0.4                 0.4
# 31385     370           -             -            0.3                 0.2
# 31387      35           -             1              -                 0.5
# 31456     120           -             -            0.5                 0.5
#
#        Dribble Fouled per game Offsides per game Dispossessed per game  \
# 333        NaN             1.3                 -                   1.6
# 372        NaN             2.7                 -                   2.3
# 471        NaN             1.5               0.1                   0.4
# 494        NaN             0.7                 -                   0.6
# 549        NaN               1                 -                   0.5
# ...        ...             ...               ...                   ...
# 31353      NaN             0.7                 -                   0.8
# 31355      NaN             0.3               0.1                   0.3
# 31385      NaN             0.3                 -                   0.5
# 31387      NaN             0.3                 -                   0.3
# 31456      NaN             0.5                 -                     2
#
#       Bad control per game  Rating      League  Saison Dribbles per game
# 333                    0.8    7.35  Bundesliga    2014               1.7
# 372                      1    7.17  Bundesliga    2014                 1
# 471                    1.2    6.90  Bundesliga    2014               1.8
# 494                    0.5    6.85  Bundesliga    2014               0.7
# 549                    0.5    6.72  Bundesliga    2014               0.4
# ...                    ...     ...         ...     ...               ...
# 31353                  0.5    6.33      Ligue1    2016               0.4
# 31355                  0.4    6.33      Ligue1    2016               0.3
# 31385                  0.5    6.24      Ligue1    2016               0.6
# 31387                  0.3    6.24      Ligue1    2016                 -
# 31456                    1    5.97      Ligue1    2016               0.5
#
# [1140 rows x 19 columns]

# %%
positions = df_summary['Position'].unique()
print(positions)
# Out:
# ['M(CLR)' 'AM(CL),FW' 'M(CLR),FW' 'AM(CLR),FW' 'AM(C),FW' 'GK' 'D(R)'
#  'M(C)' 'D(R),DMC' 'D(LR),M(CLR)' 'D(CR)' 'AM(LR),FW' 'D(C)' 'M(LR),FW'
#  'AM(R),FW' 'AM(CLR)' 'D(CLR),M(R)' 'D(CLR),DMC' 'M(CR)' 'D(CL)' 'DMC'
#  'D(CR),DMC' 'D(L),M(CL)' 'D(CL),M(L)' 'D(LR),M(LR)' 'D(L),M(CR)' 'D(CLR)'
#  'D(L),M(CLR)' 'FW' 'M(CL),FW' 'M(CL)' 'D(R),M(R)' 'Midfielder'
#  'D(CR),M(R)' 'D(L),M(L)' 'AM(L),FW' 'D(LR),M(R)' 'D(LR)' 'D(L)'
#  'D(CL),DMC' 'D(R),M(CLR),FW' 'D(L),DMC,M(L)' 'D(C),DMC' 'D(CL),DMC,M(L)'
#  'D(LR),DMC,M(R)' 'M(LR)' 'AM(LR)' 'M(R),FW' 'D(R),DMC,M(R)' 'D(C),M(CL)'
#  'D(C),M(C)' 'AM(L)' 'D(CLR),M(LR)' 'AM(CL)' 'M(R)' 'M(L),FW' 'D(R),M(LR)'
#  'AM(R)' 'AM(CR)' 'Forward' 'Defender' 'AM(C)' 'M(L)' 'M(CR),FW'
#  'D(R),M(LR),FW' 'D(R),M(C)' 'D(R),M(CR)' 'M(C),FW' 'D(CL),M(C)'
#  'D(L),M(C)' 'D(CLR),M(C)' 'D(LR),M(CL)' 'D(L),DMC' 'D(CR),M(C)'
#  'D(LR),M(CR)' 'D(CR),M(CR)' 'D(CR),M(CL)' 'D(C),M(CR)' 'D(LR),M(C)'
#  'D(R),M(CLR)' 'D(C),M(CR),FW' 'AM(CR),FW' 'Goalkeeper' ' AM(CLR)  '
#  ' FW  ' ' AM(CR),FW  ' ' AM(C)  ' ' D(C)  ' ' AM(LR),FW  ' ' D(L),M(L)  '
#  ' M(CL)  ' ' DMC,M(L)  ' ' AM(CL),FW  ' ' M(C)  ' ' M(CLR),FW  '
#  ' D(CLR),DMC  ' ' AM(CLR),FW  ' ' D(CLR),M(R)  ' ' D(C),M(C)  ' ' DMC  '
#  ' M(CLR)  ' ' D(CR)  ' ' D(CL)  ' ' GK  ' ' D(C),M(C),FW  ' ' M(L)  '
#  ' D(R),M(CLR),FW  ' ' D(CL),M(L)  ' ' M(LR)  ' ' AM(CR)  ' ' D(L)  '
#  ' M(LR),FW  ' ' D(L),DMC,M(L)  ' ' AM(C),FW  ' ' M(CR),FW  '
#  ' AM(R),FW  ' ' D(CLR),M(LR)  ' ' D(C),DMC  ' ' D(LR),M(R)  '
#  ' D(R),M(LR)  ' ' D(CR),M(R)  ' ' M(R)  ' ' D(R),M(R)  ' ' D(LR),M(L)  '
#  ' D(R)  ' ' D(CR),DMC  ' ' D(R),M(CLR)  ' ' D(C),M(CLR)  ' ' M(CR)  '
#  ' D(R),DMC,M(LR)  ' ' Forward  ' ' DMC,M(LR)  ' ' D(LR)  '
#  ' D(LR),M(LR)  ' ' D(L),M(CL)  ' ' D(CR),M(LR)  ' ' AM(CL)  '
#  ' Midfielder  ' ' D(C),M(L)  ' ' AM(L)  ' ' D(R),M(CR)  ' ' DMC,M(R)  '
#  'D(CL),M(CLR)' 'D(R),M(L)' 'DMC,M(L)' 'DMC,M(R)' 'D(CLR),M(L)'
#  'D(R),M(CR),FW' 'D(CLR),DMC,M(R)' 'D(L),M(LR)' 'D(C),M(R)'
#  'D(C),DMC,M(R)' 'D(R),M(R),FW' 'D(C),M(C),FW' 'D(LR),DMC' 'D(LR),M(L)'
#  'D(CL),M(CR)' 'D(CLR),M(CR)' 'D(C),M(CLR)' ' D(L),M(CLR)  ' ' AM(L),FW  '
#  ' M(CL),FW  ' ' D(R),M(CR),FW  ' ' D(L),M(C)  ' ' D(CL),DMC  '
#  ' M(C),FW  ' ' AM(R)  ' ' D(CLR)  ' ' D(LR),M(CLR)  ' ' AM(LR)  '
#  ' D(R),DMC  ' ' D(CLR),DMC,M(R)  ' ' D(L),M(LR)  ' ' D(CR),DMC,M(R)  '
#  ' D(CR),M(CR)  ' 'D(C),M(L)' 'D(CR),DMC,M(L)' 'D(CL),M(R)'
#  'D(C),M(CL),FW' 'D(C),M(R),FW' 'midfielder' 'D(CLR),DMC,M(LR)'
#  'D(L),M(R)' ' D(CL),DMC,M(L)  ' ' D(C),M(CL)  ' ' D(CL),M(CL)  '
#  ' D(L),M(CR)  ' ' D(R),M(C)  ' ' D(CR),M(C)  ' ' D(R),DMC,M(R)  '
#  'D(C),FW' 'D(R),DMC,M(LR)' ' M(L),FW  ' ' D(LR),M(CLR),FW  '
#  ' D(CLR),M(CLR)  ' 'forward' 'D(CR),M(CLR)' ' D(CLR),M(L)  '
#  ' D(LR),DMC  ' ' D(L),M(LR),FW  ' ' M(R),FW  ' 'D(C),DMC,M(L)'
#  ' D(L),M(CLR),FW  ' ' D(LR),DMC,M(LR)  ' ' D(LR),DMC,M(L)  '
#  ' D(LR),M(CL)  ' ' D(R),M(R),FW  ' 'D(L),M(LR),FW' ' D(L),DMC  '
#  'D(C),M(CLR),FW' 'D(CR),M(CR),FW' 'D(R),M(L),FW' 'D(CR),M(LR)'
#  ' D(C),M(CR)  ' 'D(CL),FW' 'D(CL),M(CL)']

# %%
import re

def remove_parentheses(text):
    return re.sub(r'\([^()]*\)', '', text)

texte = "AM(CLR),FW"
texte_sans_parentheses = remove_parentheses(texte)
print(texte_sans_parentheses)
# Out:
# AM,FW

# %%
df_offensive["Position"] = df_offensive["Position"].apply(remove_parentheses)
df_passing["Position"] = df_passing["Position"].apply(remove_parentheses)
df_summary["Position"] = df_summary["Position"].apply(remove_parentheses)
df_defensive["Position"] = df_defensive["Position"].apply(remove_parentheses)
positions = df_summary['Position'].unique()
print(positions)
# Out:
# ['M' 'AM,FW' 'M,FW' 'GK' 'D' 'D,DMC' 'D,M' 'AM' 'DMC' 'FW' 'Midfielder'
#  'D,M,FW' 'D,DMC,M' 'Forward' 'Defender' 'Goalkeeper' ' AM  ' ' FW  '
#  ' AM,FW  ' ' D  ' ' D,M  ' ' M  ' ' DMC,M  ' ' M,FW  ' ' D,DMC  '
#  ' DMC  ' ' GK  ' ' D,M,FW  ' ' D,DMC,M  ' ' Forward  ' ' Midfielder  '
#  'DMC,M' 'midfielder' 'D,FW' 'forward']

# %%
def replace_position(position):
    if "D" in position:
        if "M" in position:
            if "FW" in position:
                position = "Defender, Midfielder, Forward"
            else:
                position = "Defender, Midfielder"
        elif "FW" in position:
            position = "Defender, Forward"
        else:
            position = "Defender"
    elif "M" in position:
        if "FW" in position:
            position = "Midfielder, Forward"
        else:
            position = "Midfielder"
    elif "FW" in position:
        position = "Forward"
    else:
        position = position
    return position

df_offensive['Position'].replace(['midfielder'], 'Midfielder', regex=False, inplace=True)
df_offensive['Position'].replace(['forward'], 'Forward', regex=False, inplace=True)

# %%
df_offensive["Position"] = df_offensive["Position"].apply(replace_position)
positions = df_offensive['Position'].unique()
print(positions)
# Out:
# ['Midfielder, Forward' 'Defender, Midfielder' 'Defender' 'Forward'
#  'Midfielder' 'Defender, Midfielder, Forward' ' GK  ' 'GK' 'Goalkeeper'
#  'Defender, Forward' ' Forward  ']

# %%
df_passing["Position"] = df_passing["Position"].apply(replace_position)
df_passing['Position'].replace(['midfielder'], 'Midfielder', regex=False, inplace=True)
df_passing['Position'].replace(['forward'], 'Forward', regex=False, inplace=True)

# %%
df_summary["Position"] = df_summary["Position"].apply(replace_position)
df_summary['Position'].replace(['midfielder'], 'Midfielder', regex=False, inplace=True)
df_summary['Position'].replace(['forward'], 'Forward', regex=False, inplace=True)

# %%
df_defensive["Position"] = df_defensive["Position"].apply(replace_position)
df_defensive['Position'].replace(['midfielder'], 'Midfielder', regex=False, inplace=True)
df_defensive['Position'].replace(['forward'], 'Forward', regex=False, inplace=True)

# %% [markdown]
# ### Apps

# %%
def clean_apps(df_list):
    for df in df_list:
        if "Apps" in df.columns:
            # Créer deux nouvelles colonnes pour stocker les valeurs de départ et de remplacement
            df["Start Application"] = df["Apps"].str.extract(r"^(\d+)")
            df["Remplacement Application"] = df["Apps"].str.extract(r"\((\d+)\)$").fillna(0)

            # Transformer les colonnes en int
            df["Start Application"] = pd.to_numeric(df["Start Application"], errors="coerce")
            df["Remplacement Application"] = pd.to_numeric(df["Remplacement Application"], errors="coerce")
            # Supprimer la colonne originale
            df.drop(columns=["Apps"], inplace=True)

    return df_list

# %%
df_list = [df_defensive, df_passing, df_summary, df_offensive]

# %%
clean_apps(df_list)
# Out:
# [                 Name           Team  Age             Position  Minutes  \
#  0        Riyad Mahrez      Leicester   28           Midfielder     3058
#  1       Dimitri Payet       West Ham   32           Midfielder     2573
#  2      Alexis Sánchez        Arsenal   30  Midfielder, Forward     2446
#  3       Mousa Dembélé      Tottenham   31           Midfielder     2273
#  4          Mesut Özil        Arsenal   30           Midfielder     3049
#  ...               ...            ...  ...                  ...      ...
#  31794     Hrvoje Cale      Wolfsburg   34             Defender       29
#  31795  Marco Djuricin  Hertha Berlin   26              Forward       39
#  31796       Dawda Bah       Augsburg   35           Midfielder       16
#  31797     Daniel Batz       Freiburg   28           Goalkeeper       90
#  31798   Sandro Wieser     Hoffenheim   26             Defender       32
#
#        Tackles per game Interceptions per game Fouls per game  \
#  0                  1.4                      1            0.5
#  1                  0.8                    0.8            0.4
#  2                  1.6                    0.8            1.1
#  3                  3.6                    1.9            1.7
#  4                    1                    0.6            0.6
#  ...                ...                    ...            ...
#  31794                1                      -              1
#  31795              0.5                    0.5            1.5
#  31796                -                      -              -
#  31797                -                      -              -
#  31798                -                      -              -
#
#        Offsides per game Clearances per game Dribbled past per game  \
#  0                     -                 0.4                    1.9
#  1                     -                 0.1                    0.8
#  2                     -                 0.2                    0.8
#  3                     -                 1.1                    0.4
#  4                     -                 0.3                    1.2
#  ...                 ...                 ...                    ...
#  31794                 -                   2                      -
#  31795                 -                   -                      -
#  31796                 -                   -                      3
#  31797                 -                   -                      1
#  31798                 -                   -                      -
#
#        Outfield blocks per game Own goals  Rating         League  Saison  \
#  0                          0.1         -    7.84  PremierLeague    2015
#  1                            -         -    7.74  PremierLeague    2015
#  2                          0.1         -    7.72  PremierLeague    2015
#  3                          0.3         -    7.69  PremierLeague    2015
#  4                            -         -    7.66  PremierLeague    2015
#  ...                        ...       ...     ...            ...     ...
#  31794                        -         -    5.72     Bundesliga    2011
#  31795                        -         -    5.70     Bundesliga    2011
#  31796                        -         -    5.64     Bundesliga    2011
#  31797                        -         -    5.25     Bundesliga    2011
#  31798                        -         -    5.12     Bundesliga    2011
#
#         Start Application  Remplacement Application
#  0                     36                         1
#  1                     29                         1
#  2                     28                         2
#  3                     27                         2
#  4                     35                         0
#  ...                  ...                       ...
#  31794                  0                         1
#  31795                  0                         2
#  31796                  0                         1
#  31797                  1                         0
#  31798                  0                         1
#
#  [31799 rows x 18 columns],
#                         Name                 Team  Age             Position  \
#  0                      Nenê  Paris Saint-Germain   37           Midfielder
#  1               Eden Hazard                Lille   28  Midfielder, Forward
#  2          Benjamin Lecomte              Lorient   28                   GK
#  3          Laurent Pionnier          Montpellier   37                   GK
#  4            Olivier Giroud          Montpellier   32              Forward
#  ...                     ...                  ...  ...                  ...
#  32085        Brandon Comley  Queens Park Rangers   23           Midfielder
#  32086      Valentin Roberge           Sunderland   32             Defender
#  32087  Gary Taylor-Fletcher            Leicester   38  Midfielder, Forward
#  32088        Chung-Yong Lee       Crystal Palace   30           Midfielder
#  32089          Cole Kpekawa  Queens Park Rangers   23             Defender
#
#         Minutes Total Assists Key passes per game Passes per game  \
#  0         3037            11                 3.7            46.8
#  1         3212            16                 2.5            52.0
#  2          428             -                   -            13.8
#  3          360             -                   -            23.0
#  4         3202             9                 1.3            23.6
#  ...        ...           ...                 ...             ...
#  32085       10             -                   -              11
#  32086       90             -                   -              33
#  32087       17             -                   -               7
#  32088       91             -                   -              13
#  32089        5             -                   -               3
#
#        Pass success percentage Crosses per game Long balls per game  \
#  0                        74.8              2.3                 2.6
#  1                        81.9              0.8                 2.1
#  2                        69.6                -                   5
#  3                        72.8                -                 8.8
#  4                        69.1              0.1                 0.5
#  ...                       ...              ...                 ...
#  32085                    90.9                -                   1
#  32086                    81.8                -                   3
#  32087                    85.7                -                   -
#  32088                    69.2              0.3                 0.7
#  32089                    33.3                -                   -
#
#        Through balls per game  Rating         League  Saison  \
#  0                        0.7    7.94         Ligue1    2011
#  1                        0.4    7.80         Ligue1    2011
#  2                          -    7.67         Ligue1    2011
#  3                          -    7.59         Ligue1    2011
#  4                          -    7.59         Ligue1    2011
#  ...                      ...     ...            ...     ...
#  32085                      -    5.89  PremierLeague    2014
#  32086                      -    5.87  PremierLeague    2014
#  32087                      -    5.79  PremierLeague    2014
#  32088                      -    5.74  PremierLeague    2014
#  32089                      -    5.24  PremierLeague    2014
#
#         Start Application  Remplacement Application
#  0                     35                         0
#  1                     35                         3
#  2                      4                         1
#  3                      4                         0
#  4                     36                         0
#  ...                  ...                       ...
#  32085                  0                         1
#  32086                  1                         0
#  32087                  0                         1
#  32088                  1                         2
#  32089                  0                         1
#
#  [32090 rows x 17 columns],
#                            Name              Team  Age              Position  \
#  0                     Coutinho         Liverpool   27            Midfielder
#  1                Sergio Agüero   Manchester City   31   Midfielder, Forward
#  2      Alex Oxlade Chamberlain           Arsenal   25            Midfielder
#  3              Kevin De Bruyne   Manchester City   28   Midfielder, Forward
#  4                 Henri Saivet  Newcastle United   28   Midfielder, Forward
#  ...                        ...               ...  ...                   ...
#  32085            Tammy Abraham           Chelsea   21               Forward
#  32086               Ivan Toney  Newcastle United   23               Forward
#  32087            Hiram Boateng    Crystal Palace   23            Midfielder
#  32088              Adam Bogdan         Liverpool   31                    GK
#  32089         Pedro Chirivella         Liverpool   22  Defender, Midfielder
#
#         Minutes Total Goals Total Assists Yellow cards Red cards  \
#  0         1116           7             6            -         -
#  1         1969          21             6            2         -
#  2          242           -             -            -         -
#  3         3085           8            16            2         -
#  4           84           1             -            -         -
#  ...        ...         ...           ...          ...       ...
#  32085       53           -             -            -         -
#  32086       10           -             -            -         -
#  32087       18           -             -            -         -
#  32088      180           -             -            -         -
#  32089       46           -             -            -         -
#
#        Shots per game Pass success percentage Aerials won per game  \
#  0                3.9                    78.8                  0.1
#  1                3.8                    82.8                  0.4
#  2                  3                    84.6                  1.3
#  3                2.5                    83.4                  0.4
#  4                  1                    62.5                    2
#  ...              ...                     ...                  ...
#  32085              1                      70                  0.5
#  32086              -                    66.7                    -
#  32087              1                      75                    -
#  32088              -                    46.2                    -
#  32089              -                    72.7                    -
#
#        Man of the match  Rating         League  Saison  Start Application  \
#  0                    6    8.03  PremierLeague    2017                 13
#  1                    4    7.81  PremierLeague    2017                 22
#  2                    1    7.81  PremierLeague    2017                  3
#  3                    8    7.80  PremierLeague    2017                 36
#  4                    -    7.70  PremierLeague    2017                  1
#  ...                ...     ...            ...     ...                ...
#  32085                -    5.96  PremierLeague    2015                  0
#  32086                -    5.94  PremierLeague    2015                  0
#  32087                -    5.90  PremierLeague    2015                  0
#  32088                -    5.60  PremierLeague    2015                  2
#  32089                -    5.31  PremierLeague    2015                  1
#
#         Remplacement Application
#  0                             1
#  1                             3
#  2                             0
#  3                             1
#  4                             0
#  ...                         ...
#  32085                         2
#  32086                         2
#  32087                         1
#  32088                         0
#  32089                         0
#
#  [32090 rows x 18 columns],
#                           Name        Team  Age              Position Minutes  \
#  0             Kevin De Bruyne    Man City   31   Midfielder, Forward   25(5)
#  1               Mohamed Salah   Liverpool   30   Midfielder, Forward   30(5)
#  2      Trent Alexander-Arnold   Liverpool   24  Defender, Midfielder      32
#  3               Son Heung-Min   Tottenham   30   Midfielder, Forward      35
#  4                  Harry Kane   Tottenham   29   Midfielder, Forward   36(1)
#  ...                       ...         ...  ...                   ...     ...
#  32085           Clément Vidal  AC Ajaccio   22              Defender   11(5)
#  32086             Sada Thioub      Angers   27            Midfielder   5(14)
#  32087            Lebo Mothiba  Strasbourg   27               Forward   1(13)
#  32088      Veljko Birmancevic    Toulouse   25            Midfielder   1(17)
#  32089        Karamoko Dembélé       Brest   20             Forward     0(14)
#
#        Total goals Total Assists Shots per game Key passes per game  Dribble  \
#  0              15             8            2.6                 2.9      1.0
#  1              23            13            4.0                 1.8      1.5
#  2               2            12            1.6                 2.8      0.6
#  3              23             7            2.5                 2.1      1.5
#  4              17             9            3.6                 1.4      1.5
#  ...           ...           ...            ...                 ...      ...
#  32085           0             0            0.6                 0.1      0.0
#  32086           0             1            0.4                 0.5      0.3
#  32087           2             0            0.4                 0.0      0.1
#  32088           0             0            0.3                 0.1      0.1
#  32089           0             0            0.3                 0.2      0.1
#
#        Fouled per game Offsides per game Dispossessed per game  \
#  0                 0.9               0.1                   0.7
#  1                 0.7               0.3                   2.3
#  2                 0.2               0.3                   0.6
#  3                 1.0               0.5                   1.3
#  4                 1.5               0.4                   1.6
#  ...               ...               ...                   ...
#  32085             0.6               0.1                   0.2
#  32086             0.2               0.0                   0.7
#  32087             0.4               0.0                   0.3
#  32088             0.3               0.0                   0.1
#  32089             0.6               0.0                   0.5
#
#        Bad control per game  Rating  League  Saison Dribbles per game  \
#  0                      1.3    7.63  LaLiga    2020               NaN
#  1                      2.8    7.54  LaLiga    2020               NaN
#  2                      1.3    7.52  LaLiga    2020               NaN
#  3                      2.1    7.51  LaLiga    2020               NaN
#  4                      2.6    7.45  LaLiga    2020               NaN
#  ...                    ...     ...     ...     ...               ...
#  32085                  0.2    6.18  Ligue1    2022               NaN
#  32086                  0.6    6.17  Ligue1    2022               NaN
#  32087                  0.5    6.15  Ligue1    2022               NaN
#  32088                  0.5    6.13  Ligue1    2022               NaN
#  32089                  0.5    6.06  Ligue1    2022               NaN
#
#         Start Application  Remplacement Application
#  0                    NaN                         0
#  1                    NaN                         0
#  2                    NaN                         0
#  3                    NaN                         0
#  4                    NaN                         0
#  ...                  ...                       ...
#  32085                NaN                         0
#  32086                NaN                         0
#  32087                NaN                         0
#  32088                NaN                         0
#  32089                NaN                         0
#
#  [32090 rows x 20 columns]]

# %%
df_defensive
# Out:
#                  Name           Team  Age             Position  Minutes  \
# 0        Riyad Mahrez      Leicester   28           Midfielder     3058
# 1       Dimitri Payet       West Ham   32           Midfielder     2573
# 2      Alexis Sánchez        Arsenal   30  Midfielder, Forward     2446
# 3       Mousa Dembélé      Tottenham   31           Midfielder     2273
# 4          Mesut Özil        Arsenal   30           Midfielder     3049
# ...               ...            ...  ...                  ...      ...
# 31794     Hrvoje Cale      Wolfsburg   34             Defender       29
# 31795  Marco Djuricin  Hertha Berlin   26              Forward       39
# 31796       Dawda Bah       Augsburg   35           Midfielder       16
# 31797     Daniel Batz       Freiburg   28           Goalkeeper       90
# 31798   Sandro Wieser     Hoffenheim   26             Defender       32
#
#       Tackles per game Interceptions per game Fouls per game  \
# 0                  1.4                      1            0.5
# 1                  0.8                    0.8            0.4
# 2                  1.6                    0.8            1.1
# 3                  3.6                    1.9            1.7
# 4                    1                    0.6            0.6
# ...                ...                    ...            ...
# 31794                1                      -              1
# 31795              0.5                    0.5            1.5
# 31796                -                      -              -
# 31797                -                      -              -
# 31798                -                      -              -
#
#       Offsides per game Clearances per game Dribbled past per game  \
# 0                     -                 0.4                    1.9
# 1                     -                 0.1                    0.8
# 2                     -                 0.2                    0.8
# 3                     -                 1.1                    0.4
# 4                     -                 0.3                    1.2
# ...                 ...                 ...                    ...
# 31794                 -                   2                      -
# 31795                 -                   -                      -
# 31796                 -                   -                      3
# 31797                 -                   -                      1
# 31798                 -                   -                      -
#
#       Outfield blocks per game Own goals  Rating         League  Saison  \
# 0                          0.1         -    7.84  PremierLeague    2015
# 1                            -         -    7.74  PremierLeague    2015
# 2                          0.1         -    7.72  PremierLeague    2015
# 3                          0.3         -    7.69  PremierLeague    2015
# 4                            -         -    7.66  PremierLeague    2015
# ...                        ...       ...     ...            ...     ...
# 31794                        -         -    5.72     Bundesliga    2011
# 31795                        -         -    5.70     Bundesliga    2011
# 31796                        -         -    5.64     Bundesliga    2011
# 31797                        -         -    5.25     Bundesliga    2011
# 31798                        -         -    5.12     Bundesliga    2011
#
#        Start Application  Remplacement Application
# 0                     36                         1
# 1                     29                         1
# 2                     28                         2
# 3                     27                         2
# 4                     35                         0
# ...                  ...                       ...
# 31794                  0                         1
# 31795                  0                         2
# 31796                  0                         1
# 31797                  1                         0
# 31798                  0                         1
#
# [31799 rows x 18 columns]

# %%
df_defensive.dtypes
# Out:
# Name                         object
# Team                         object
# Age                           int64
# Position                     object
# Minutes                       int64
# Tackles per game             object
# Interceptions per game       object
# Fouls per game               object
# Offsides per game            object
# Clearances per game          object
# Dribbled past per game       object
# Outfield blocks per game     object
# Own goals                    object
# Rating                      float64
# League                       object
# Saison                        int64
# Start Application             int64
# Remplacement Application      int64
# dtype: object

# %% [markdown]
# ### Verification des données

# %%
df_dmc = df_offensive.loc[df_offensive["Position"] == "Defender, Midfielder"]
print(df_dmc)
# Out:
#                          Name        Team  Age              Position Minutes  \
# 2      Trent Alexander-Arnold   Liverpool   24  Defender, Midfielder      32
# 5                       Rodri    Man City   26  Defender, Midfielder      33
# 6                João Cancelo    Man City   28  Defender, Midfielder      36
# 12                Reece James     Chelsea   23  Defender, Midfielder   22(4)
# 14           Andrew Robertson   Liverpool   28  Defender, Midfielder      29
# ...                       ...         ...  ...                   ...     ...
# 32069        Ibrahima Sissoko  Strasbourg   25  Defender, Midfielder    8(8)
# 32072       Sébastien Corchia      Nantes   32  Defender, Midfielder   4(15)
# 32077           Ismail Jakobs      Monaco   23  Defender, Midfielder   5(17)
# 32081           Batista Mendy      Angers   23  Defender, Midfielder      23
# 32084            Eliot Matazo      Monaco   21  Defender, Midfielder    8(5)
#
#       Total goals Total Assists Shots per game Key passes per game  Dribble  \
# 2               2            12            1.6                 2.8      0.6
# 5               7             2            1.4                 0.9      0.4
# 6               1             7            2.3                 1.1      1.6
# 12              5             9            1.4                 1.8      1.4
# 14              3            10            0.6                 1.9      0.4
# ...           ...           ...            ...                 ...      ...
# 32069           0             0            0.6                 0.2      0.1
# 32072           0             1            0.2                 0.3      0.1
# 32077           0             2            0.5                 0.3      0.1
# 32081           0             0            0.4                 0.5      0.7
# 32084           0             0            0.2                 0.0      0.1
#
#       Fouled per game Offsides per game Dispossessed per game  \
# 2                 0.2               0.3                   0.6
# 5                 0.6               0.0                   0.7
# 6                 0.7               0.1                   0.7
# 12                1.2               0.2                   0.8
# 14                0.3               0.1                   0.5
# ...               ...               ...                   ...
# 32069             0.8               0.1                   0.8
# 32072             0.8               0.1                   0.3
# 32077             0.2               0.0                   0.2
# 32081             1.1               0.0                   0.8
# 32084             0.3               0.0                   0.5
#
#       Bad control per game  Rating  League  Saison Dribbles per game  \
# 2                      1.3    7.52  LaLiga    2020               NaN
# 5                      0.5    7.43  LaLiga    2020               NaN
# 6                      1.3    7.42  LaLiga    2020               NaN
# 12                     1.0    7.24  LaLiga    2020               NaN
# 14                     0.8    7.23  LaLiga    2020               NaN
# ...                    ...     ...     ...     ...               ...
# 32069                  1.2    6.27  Ligue1    2022               NaN
# 32072                  0.5    6.26  Ligue1    2022               NaN
# 32077                  0.4    6.25  Ligue1    2022               NaN
# 32081                  0.7    6.23  Ligue1    2022               NaN
# 32084                  0.2    6.19  Ligue1    2022               NaN
#
#        Start Application  Remplacement Application
# 2                    NaN                         0
# 5                    NaN                         0
# 6                    NaN                         0
# 12                   NaN                         0
# 14                   NaN                         0
# ...                  ...                       ...
# 32069                NaN                         0
# 32072                NaN                         0
# 32077                NaN                         0
# 32081                NaN                         0
# 32084                NaN                         0
#
# [6720 rows x 20 columns]

# %%
df_offensive
# Out:
#                          Name        Team  Age              Position Minutes  \
# 0             Kevin De Bruyne    Man City   31   Midfielder, Forward   25(5)
# 1               Mohamed Salah   Liverpool   30   Midfielder, Forward   30(5)
# 2      Trent Alexander-Arnold   Liverpool   24  Defender, Midfielder      32
# 3               Son Heung-Min   Tottenham   30   Midfielder, Forward      35
# 4                  Harry Kane   Tottenham   29   Midfielder, Forward   36(1)
# ...                       ...         ...  ...                   ...     ...
# 32085           Clément Vidal  AC Ajaccio   22              Defender   11(5)
# 32086             Sada Thioub      Angers   27            Midfielder   5(14)
# 32087            Lebo Mothiba  Strasbourg   27               Forward   1(13)
# 32088      Veljko Birmancevic    Toulouse   25            Midfielder   1(17)
# 32089        Karamoko Dembélé       Brest   20             Forward     0(14)
#
#       Total goals Total Assists Shots per game Key passes per game  Dribble  \
# 0              15             8            2.6                 2.9      1.0
# 1              23            13            4.0                 1.8      1.5
# 2               2            12            1.6                 2.8      0.6
# 3              23             7            2.5                 2.1      1.5
# 4              17             9            3.6                 1.4      1.5
# ...           ...           ...            ...                 ...      ...
# 32085           0             0            0.6                 0.1      0.0
# 32086           0             1            0.4                 0.5      0.3
# 32087           2             0            0.4                 0.0      0.1
# 32088           0             0            0.3                 0.1      0.1
# 32089           0             0            0.3                 0.2      0.1
#
#       Fouled per game Offsides per game Dispossessed per game  \
# 0                 0.9               0.1                   0.7
# 1                 0.7               0.3                   2.3
# 2                 0.2               0.3                   0.6
# 3                 1.0               0.5                   1.3
# 4                 1.5               0.4                   1.6
# ...               ...               ...                   ...
# 32085             0.6               0.1                   0.2
# 32086             0.2               0.0                   0.7
# 32087             0.4               0.0                   0.3
# 32088             0.3               0.0                   0.1
# 32089             0.6               0.0                   0.5
#
#       Bad control per game  Rating  League  Saison Dribbles per game  \
# 0                      1.3    7.63  LaLiga    2020               NaN
# 1                      2.8    7.54  LaLiga    2020               NaN
# 2                      1.3    7.52  LaLiga    2020               NaN
# 3                      2.1    7.51  LaLiga    2020               NaN
# 4                      2.6    7.45  LaLiga    2020               NaN
# ...                    ...     ...     ...     ...               ...
# 32085                  0.2    6.18  Ligue1    2022               NaN
# 32086                  0.6    6.17  Ligue1    2022               NaN
# 32087                  0.5    6.15  Ligue1    2022               NaN
# 32088                  0.5    6.13  Ligue1    2022               NaN
# 32089                  0.5    6.06  Ligue1    2022               NaN
#
#        Start Application  Remplacement Application
# 0                    NaN                         0
# 1                    NaN                         0
# 2                    NaN                         0
# 3                    NaN                         0
# 4                    NaN                         0
# ...                  ...                       ...
# 32085                NaN                         0
# 32086                NaN                         0
# 32087                NaN                         0
# 32088                NaN                         0
# 32089                NaN                         0
#
# [32090 rows x 20 columns]

# %%
saisons = df_offensive['Saison'].unique()
print(saisons)
# Out:
# [2020 2014 2011 2012 2010 2018 2017 2009 2019 2015 2022 2016 2021 2013]

# %%
df_passing
# Out:
#                        Name                 Team  Age             Position  \
# 0                      Nenê  Paris Saint-Germain   37           Midfielder
# 1               Eden Hazard                Lille   28  Midfielder, Forward
# 2          Benjamin Lecomte              Lorient   28                   GK
# 3          Laurent Pionnier          Montpellier   37                   GK
# 4            Olivier Giroud          Montpellier   32              Forward
# ...                     ...                  ...  ...                  ...
# 32085        Brandon Comley  Queens Park Rangers   23           Midfielder
# 32086      Valentin Roberge           Sunderland   32             Defender
# 32087  Gary Taylor-Fletcher            Leicester   38  Midfielder, Forward
# 32088        Chung-Yong Lee       Crystal Palace   30           Midfielder
# 32089          Cole Kpekawa  Queens Park Rangers   23             Defender
#
#        Minutes Total Assists Key passes per game Passes per game  \
# 0         3037            11                 3.7            46.8
# 1         3212            16                 2.5            52.0
# 2          428             -                   -            13.8
# 3          360             -                   -            23.0
# 4         3202             9                 1.3            23.6
# ...        ...           ...                 ...             ...
# 32085       10             -                   -              11
# 32086       90             -                   -              33
# 32087       17             -                   -               7
# 32088       91             -                   -              13
# 32089        5             -                   -               3
#
#       Pass success percentage Crosses per game Long balls per game  \
# 0                        74.8              2.3                 2.6
# 1                        81.9              0.8                 2.1
# 2                        69.6                -                   5
# 3                        72.8                -                 8.8
# 4                        69.1              0.1                 0.5
# ...                       ...              ...                 ...
# 32085                    90.9                -                   1
# 32086                    81.8                -                   3
# 32087                    85.7                -                   -
# 32088                    69.2              0.3                 0.7
# 32089                    33.3                -                   -
#
#       Through balls per game  Rating         League  Saison  \
# 0                        0.7    7.94         Ligue1    2011
# 1                        0.4    7.80         Ligue1    2011
# 2                          -    7.67         Ligue1    2011
# 3                          -    7.59         Ligue1    2011
# 4                          -    7.59         Ligue1    2011
# ...                      ...     ...            ...     ...
# 32085                      -    5.89  PremierLeague    2014
# 32086                      -    5.87  PremierLeague    2014
# 32087                      -    5.79  PremierLeague    2014
# 32088                      -    5.74  PremierLeague    2014
# 32089                      -    5.24  PremierLeague    2014
#
#        Start Application  Remplacement Application
# 0                     35                         0
# 1                     35                         3
# 2                      4                         1
# 3                      4                         0
# 4                     36                         0
# ...                  ...                       ...
# 32085                  0                         1
# 32086                  1                         0
# 32087                  0                         1
# 32088                  1                         2
# 32089                  0                         1
#
# [32090 rows x 17 columns]

# %%
saisons = df_passing['Saison'].unique()
print(saisons)
# Out:
# [2011 2013 2017 2014 2019 2009 2012 2016 2018 2010 2015 2020 2022 2021]

# %%
df_summary
# Out:
#                           Name              Team  Age              Position  \
# 0                     Coutinho         Liverpool   27            Midfielder
# 1                Sergio Agüero   Manchester City   31   Midfielder, Forward
# 2      Alex Oxlade Chamberlain           Arsenal   25            Midfielder
# 3              Kevin De Bruyne   Manchester City   28   Midfielder, Forward
# 4                 Henri Saivet  Newcastle United   28   Midfielder, Forward
# ...                        ...               ...  ...                   ...
# 32085            Tammy Abraham           Chelsea   21               Forward
# 32086               Ivan Toney  Newcastle United   23               Forward
# 32087            Hiram Boateng    Crystal Palace   23            Midfielder
# 32088              Adam Bogdan         Liverpool   31                    GK
# 32089         Pedro Chirivella         Liverpool   22  Defender, Midfielder
#
#        Minutes Total Goals Total Assists Yellow cards Red cards  \
# 0         1116           7             6            -         -
# 1         1969          21             6            2         -
# 2          242           -             -            -         -
# 3         3085           8            16            2         -
# 4           84           1             -            -         -
# ...        ...         ...           ...          ...       ...
# 32085       53           -             -            -         -
# 32086       10           -             -            -         -
# 32087       18           -             -            -         -
# 32088      180           -             -            -         -
# 32089       46           -             -            -         -
#
#       Shots per game Pass success percentage Aerials won per game  \
# 0                3.9                    78.8                  0.1
# 1                3.8                    82.8                  0.4
# 2                  3                    84.6                  1.3
# 3                2.5                    83.4                  0.4
# 4                  1                    62.5                    2
# ...              ...                     ...                  ...
# 32085              1                      70                  0.5
# 32086              -                    66.7                    -
# 32087              1                      75                    -
# 32088              -                    46.2                    -
# 32089              -                    72.7                    -
#
#       Man of the match  Rating         League  Saison  Start Application  \
# 0                    6    8.03  PremierLeague    2017                 13
# 1                    4    7.81  PremierLeague    2017                 22
# 2                    1    7.81  PremierLeague    2017                  3
# 3                    8    7.80  PremierLeague    2017                 36
# 4                    -    7.70  PremierLeague    2017                  1
# ...                ...     ...            ...     ...                ...
# 32085                -    5.96  PremierLeague    2015                  0
# 32086                -    5.94  PremierLeague    2015                  0
# 32087                -    5.90  PremierLeague    2015                  0
# 32088                -    5.60  PremierLeague    2015                  2
# 32089                -    5.31  PremierLeague    2015                  1
#
#        Remplacement Application
# 0                             1
# 1                             3
# 2                             0
# 3                             1
# 4                             0
# ...                         ...
# 32085                         2
# 32086                         2
# 32087                         1
# 32088                         0
# 32089                         0
#
# [32090 rows x 18 columns]

# %%
saisons = df_passing['Saison'].unique()
print(saisons)
# Out:
# [2011 2013 2017 2014 2019 2009 2012 2016 2018 2010 2015 2020 2022 2021]

# %%
df_defensive
# Out:
#                  Name           Team  Age             Position  Minutes  \
# 0        Riyad Mahrez      Leicester   28           Midfielder     3058
# 1       Dimitri Payet       West Ham   32           Midfielder     2573
# 2      Alexis Sánchez        Arsenal   30  Midfielder, Forward     2446
# 3       Mousa Dembélé      Tottenham   31           Midfielder     2273
# 4          Mesut Özil        Arsenal   30           Midfielder     3049
# ...               ...            ...  ...                  ...      ...
# 31794     Hrvoje Cale      Wolfsburg   34             Defender       29
# 31795  Marco Djuricin  Hertha Berlin   26              Forward       39
# 31796       Dawda Bah       Augsburg   35           Midfielder       16
# 31797     Daniel Batz       Freiburg   28           Goalkeeper       90
# 31798   Sandro Wieser     Hoffenheim   26             Defender       32
#
#       Tackles per game Interceptions per game Fouls per game  \
# 0                  1.4                      1            0.5
# 1                  0.8                    0.8            0.4
# 2                  1.6                    0.8            1.1
# 3                  3.6                    1.9            1.7
# 4                    1                    0.6            0.6
# ...                ...                    ...            ...
# 31794                1                      -              1
# 31795              0.5                    0.5            1.5
# 31796                -                      -              -
# 31797                -                      -              -
# 31798                -                      -              -
#
#       Offsides per game Clearances per game Dribbled past per game  \
# 0                     -                 0.4                    1.9
# 1                     -                 0.1                    0.8
# 2                     -                 0.2                    0.8
# 3                     -                 1.1                    0.4
# 4                     -                 0.3                    1.2
# ...                 ...                 ...                    ...
# 31794                 -                   2                      -
# 31795                 -                   -                      -
# 31796                 -                   -                      3
# 31797                 -                   -                      1
# 31798                 -                   -                      -
#
#       Outfield blocks per game Own goals  Rating         League  Saison  \
# 0                          0.1         -    7.84  PremierLeague    2015
# 1                            -         -    7.74  PremierLeague    2015
# 2                          0.1         -    7.72  PremierLeague    2015
# 3                          0.3         -    7.69  PremierLeague    2015
# 4                            -         -    7.66  PremierLeague    2015
# ...                        ...       ...     ...            ...     ...
# 31794                        -         -    5.72     Bundesliga    2011
# 31795                        -         -    5.70     Bundesliga    2011
# 31796                        -         -    5.64     Bundesliga    2011
# 31797                        -         -    5.25     Bundesliga    2011
# 31798                        -         -    5.12     Bundesliga    2011
#
#        Start Application  Remplacement Application
# 0                     36                         1
# 1                     29                         1
# 2                     28                         2
# 3                     27                         2
# 4                     35                         0
# ...                  ...                       ...
# 31794                  0                         1
# 31795                  0                         2
# 31796                  0                         1
# 31797                  1                         0
# 31798                  0                         1
#
# [31799 rows x 18 columns]

# %%
saisons = df_passing['Saison'].unique()
print(saisons)
# Out:
# [2011 2013 2017 2014 2019 2009 2012 2016 2018 2010 2015 2020 2022 2021]

# %% [markdown]
# #### Nombre de Lignes nulles par colonnes

# %%
# Liste des valeurs manquantes à remplacer
missing_values = ['', ' ', '-', '--', 'NA', 'N/A', 'n/a', 'NaN', 'nan', '.', '..', '...']

# Remplacer les valeurs manquantes par NaN
df_defensive_null = df_defensive.replace(missing_values, pd.NA)
# Compter le nombre de valeurs nulles pour chaque colonne
null_counts = df_defensive_null.isna().sum()

# Afficher le nombre de valeurs nulles pour chaque colonne
print(null_counts)
# Out:
# Name                            0
# Team                            0
# Age                             0
# Position                        0
# Minutes                         0
# Tackles per game             3590
# Interceptions per game       4272
# Fouls per game               3498
# Offsides per game           17574
# Clearances per game          3368
# Dribbled past per game       4197
# Outfield blocks per game    11347
# Own goals                   25860
# Rating                          0
# League                          0
# Saison                          0
# Start Application               0
# Remplacement Application        0
# dtype: int64

# %%
df_defensive_null
# Out:
#                  Name           Team  Age             Position  Minutes  \
# 0        Riyad Mahrez      Leicester   28           Midfielder     3058
# 1       Dimitri Payet       West Ham   32           Midfielder     2573
# 2      Alexis Sánchez        Arsenal   30  Midfielder, Forward     2446
# 3       Mousa Dembélé      Tottenham   31           Midfielder     2273
# 4          Mesut Özil        Arsenal   30           Midfielder     3049
# ...               ...            ...  ...                  ...      ...
# 31794     Hrvoje Cale      Wolfsburg   34             Defender       29
# 31795  Marco Djuricin  Hertha Berlin   26              Forward       39
# 31796       Dawda Bah       Augsburg   35           Midfielder       16
# 31797     Daniel Batz       Freiburg   28           Goalkeeper       90
# 31798   Sandro Wieser     Hoffenheim   26             Defender       32
#
#       Tackles per game Interceptions per game Fouls per game  \
# 0                  1.4                      1            0.5
# 1                  0.8                    0.8            0.4
# 2                  1.6                    0.8            1.1
# 3                  3.6                    1.9            1.7
# 4                    1                    0.6            0.6
# ...                ...                    ...            ...
# 31794                1                   <NA>              1
# 31795              0.5                    0.5            1.5
# 31796             <NA>                   <NA>           <NA>
# 31797             <NA>                   <NA>           <NA>
# 31798             <NA>                   <NA>           <NA>
#
#       Offsides per game Clearances per game Dribbled past per game  \
# 0                  <NA>                 0.4                    1.9
# 1                  <NA>                 0.1                    0.8
# 2                  <NA>                 0.2                    0.8
# 3                  <NA>                 1.1                    0.4
# 4                  <NA>                 0.3                    1.2
# ...                 ...                 ...                    ...
# 31794              <NA>                   2                   <NA>
# 31795              <NA>                <NA>                   <NA>
# 31796              <NA>                <NA>                      3
# 31797              <NA>                <NA>                      1
# 31798              <NA>                <NA>                   <NA>
#
#       Outfield blocks per game Own goals  Rating         League  Saison  \
# 0                          0.1      <NA>    7.84  PremierLeague    2015
# 1                         <NA>      <NA>    7.74  PremierLeague    2015
# 2                          0.1      <NA>    7.72  PremierLeague    2015
# 3                          0.3      <NA>    7.69  PremierLeague    2015
# 4                         <NA>      <NA>    7.66  PremierLeague    2015
# ...                        ...       ...     ...            ...     ...
# 31794                     <NA>      <NA>    5.72     Bundesliga    2011
# 31795                     <NA>      <NA>    5.70     Bundesliga    2011
# 31796                     <NA>      <NA>    5.64     Bundesliga    2011
# 31797                     <NA>      <NA>    5.25     Bundesliga    2011
# 31798                     <NA>      <NA>    5.12     Bundesliga    2011
#
#        Start Application  Remplacement Application
# 0                     36                         1
# 1                     29                         1
# 2                     28                         2
# 3                     27                         2
# 4                     35                         0
# ...                  ...                       ...
# 31794                  0                         1
# 31795                  0                         2
# 31796                  0                         1
# 31797                  1                         0
# 31798                  0                         1
#
# [31799 rows x 18 columns]

# %%
# Liste des valeurs manquantes à remplacer
missing_values = ['', ' ', '-', '--', 'NA', 'N/A', 'n/a', 'NaN', 'nan', '.', '..', '...']

# Remplacer les valeurs manquantes par NaN
df_passing_null = df_passing.replace(missing_values, pd.NA)
# Compter le nombre de valeurs nulles pour chaque colonne
null_counts = df_passing_null.isna().sum()

# Afficher le nombre de valeurs nulles pour chaque colonne
print(null_counts)
# Out:
# Name                            0
# Team                            0
# Age                             0
# Position                        0
# Minutes                         0
# Total Assists               14551
# Key passes per game          5114
# Passes per game               139
# Pass success percentage       207
# Crosses per game            11489
# Long balls per game          2500
# Through balls per game      19835
# Rating                          0
# League                          0
# Saison                          0
# Start Application               0
# Remplacement Application        0
# dtype: int64

# %%
df_passing_null
# Out:
#                        Name                 Team  Age             Position  \
# 0                      Nenê  Paris Saint-Germain   37           Midfielder
# 1               Eden Hazard                Lille   28  Midfielder, Forward
# 2          Benjamin Lecomte              Lorient   28                   GK
# 3          Laurent Pionnier          Montpellier   37                   GK
# 4            Olivier Giroud          Montpellier   32              Forward
# ...                     ...                  ...  ...                  ...
# 32085        Brandon Comley  Queens Park Rangers   23           Midfielder
# 32086      Valentin Roberge           Sunderland   32             Defender
# 32087  Gary Taylor-Fletcher            Leicester   38  Midfielder, Forward
# 32088        Chung-Yong Lee       Crystal Palace   30           Midfielder
# 32089          Cole Kpekawa  Queens Park Rangers   23             Defender
#
#        Minutes Total Assists Key passes per game Passes per game  \
# 0         3037            11                 3.7            46.8
# 1         3212            16                 2.5            52.0
# 2          428          <NA>                <NA>            13.8
# 3          360          <NA>                <NA>            23.0
# 4         3202             9                 1.3            23.6
# ...        ...           ...                 ...             ...
# 32085       10          <NA>                <NA>              11
# 32086       90          <NA>                <NA>              33
# 32087       17          <NA>                <NA>               7
# 32088       91          <NA>                <NA>              13
# 32089        5          <NA>                <NA>               3
#
#       Pass success percentage Crosses per game Long balls per game  \
# 0                        74.8              2.3                 2.6
# 1                        81.9              0.8                 2.1
# 2                        69.6             <NA>                   5
# 3                        72.8             <NA>                 8.8
# 4                        69.1              0.1                 0.5
# ...                       ...              ...                 ...
# 32085                    90.9             <NA>                   1
# 32086                    81.8             <NA>                   3
# 32087                    85.7             <NA>                <NA>
# 32088                    69.2              0.3                 0.7
# 32089                    33.3             <NA>                <NA>
#
#       Through balls per game  Rating         League  Saison  \
# 0                        0.7    7.94         Ligue1    2011
# 1                        0.4    7.80         Ligue1    2011
# 2                       <NA>    7.67         Ligue1    2011
# 3                       <NA>    7.59         Ligue1    2011
# 4                       <NA>    7.59         Ligue1    2011
# ...                      ...     ...            ...     ...
# 32085                   <NA>    5.89  PremierLeague    2014
# 32086                   <NA>    5.87  PremierLeague    2014
# 32087                   <NA>    5.79  PremierLeague    2014
# 32088                   <NA>    5.74  PremierLeague    2014
# 32089                   <NA>    5.24  PremierLeague    2014
#
#        Start Application  Remplacement Application
# 0                     35                         0
# 1                     35                         3
# 2                      4                         1
# 3                      4                         0
# 4                     36                         0
# ...                  ...                       ...
# 32085                  0                         1
# 32086                  1                         0
# 32087                  0                         1
# 32088                  1                         2
# 32089                  0                         1
#
# [32090 rows x 17 columns]

# %%
# Liste des valeurs manquantes à remplacer
missing_values = ['', ' ', '-', '--', 'NA', 'N/A', 'n/a', 'NaN', 'nan', '.', '..', '...']

# Remplacer les valeurs manquantes par NaN
df_offensive_null = df_offensive.replace(missing_values, pd.NA)
# Compter le nombre de valeurs nulles pour chaque colonne
null_counts = df_offensive_null.isna().sum()

# Afficher le nombre de valeurs nulles pour chaque colonne
print(null_counts)
# Out:
# Name                            0
# Team                            0
# Age                             0
# Position                        0
# Minutes                         0
# Total goals                 14288
# Total Assists               14551
# Shots per game               4842
# Key passes per game          5114
# Dribble                     27193
# Fouled per game              3016
# Offsides per game           15245
# Dispossessed per game        4890
# Bad control per game         6277
# Rating                          0
# League                          0
# Saison                          0
# Dribbles per game           10793
# Start Application            4897
# Remplacement Application        0
# dtype: int64

# %%
df_offensive_null
# Out:
#                          Name        Team  Age              Position Minutes  \
# 0             Kevin De Bruyne    Man City   31   Midfielder, Forward   25(5)
# 1               Mohamed Salah   Liverpool   30   Midfielder, Forward   30(5)
# 2      Trent Alexander-Arnold   Liverpool   24  Defender, Midfielder      32
# 3               Son Heung-Min   Tottenham   30   Midfielder, Forward      35
# 4                  Harry Kane   Tottenham   29   Midfielder, Forward   36(1)
# ...                       ...         ...  ...                   ...     ...
# 32085           Clément Vidal  AC Ajaccio   22              Defender   11(5)
# 32086             Sada Thioub      Angers   27            Midfielder   5(14)
# 32087            Lebo Mothiba  Strasbourg   27               Forward   1(13)
# 32088      Veljko Birmancevic    Toulouse   25            Midfielder   1(17)
# 32089        Karamoko Dembélé       Brest   20             Forward     0(14)
#
#       Total goals Total Assists Shots per game Key passes per game  Dribble  \
# 0              15             8            2.6                 2.9      1.0
# 1              23            13            4.0                 1.8      1.5
# 2               2            12            1.6                 2.8      0.6
# 3              23             7            2.5                 2.1      1.5
# 4              17             9            3.6                 1.4      1.5
# ...           ...           ...            ...                 ...      ...
# 32085           0             0            0.6                 0.1      0.0
# 32086           0             1            0.4                 0.5      0.3
# 32087           2             0            0.4                 0.0      0.1
# 32088           0             0            0.3                 0.1      0.1
# 32089           0             0            0.3                 0.2      0.1
#
#       Fouled per game Offsides per game Dispossessed per game  \
# 0                 0.9               0.1                   0.7
# 1                 0.7               0.3                   2.3
# 2                 0.2               0.3                   0.6
# 3                 1.0               0.5                   1.3
# 4                 1.5               0.4                   1.6
# ...               ...               ...                   ...
# 32085             0.6               0.1                   0.2
# 32086             0.2               0.0                   0.7
# 32087             0.4               0.0                   0.3
# 32088             0.3               0.0                   0.1
# 32089             0.6               0.0                   0.5
#
#       Bad control per game  Rating  League  Saison Dribbles per game  \
# 0                      1.3    7.63  LaLiga    2020               NaN
# 1                      2.8    7.54  LaLiga    2020               NaN
# 2                      1.3    7.52  LaLiga    2020               NaN
# 3                      2.1    7.51  LaLiga    2020               NaN
# 4                      2.6    7.45  LaLiga    2020               NaN
# ...                    ...     ...     ...     ...               ...
# 32085                  0.2    6.18  Ligue1    2022               NaN
# 32086                  0.6    6.17  Ligue1    2022               NaN
# 32087                  0.5    6.15  Ligue1    2022               NaN
# 32088                  0.5    6.13  Ligue1    2022               NaN
# 32089                  0.5    6.06  Ligue1    2022               NaN
#
#        Start Application  Remplacement Application
# 0                    NaN                         0
# 1                    NaN                         0
# 2                    NaN                         0
# 3                    NaN                         0
# 4                    NaN                         0
# ...                  ...                       ...
# 32085                NaN                         0
# 32086                NaN                         0
# 32087                NaN                         0
# 32088                NaN                         0
# 32089                NaN                         0
#
# [32090 rows x 20 columns]

# %%
# Liste des valeurs manquantes à remplacer
missing_values = ['', ' ', '-', '--', 'NA', 'N/A', 'n/a', 'NaN', 'nan', '.', '..', '...']

# Remplacer les valeurs manquantes par NaN
df_summary_null = df_summary.replace(missing_values, pd.NA)
# Compter le nombre de valeurs nulles pour chaque colonne
null_counts = df_summary_null.isna().sum()

# Afficher le nombre de valeurs nulles pour chaque colonne
print(null_counts)
# Out:
# Name                            0
# Team                            0
# Age                             0
# Position                        0
# Minutes                         0
# Total Goals                 14288
# Total Assists               14551
# Yellow cards                 7388
# Red cards                   23431
# Shots per game               4842
# Pass success percentage       207
# Aerials won per game         3523
# Man of the match            17808
# Rating                          0
# League                          0
# Saison                          0
# Start Application               0
# Remplacement Application        0
# dtype: int64

# %%
df_summary_null
# Out:
#                           Name              Team  Age              Position  \
# 0                     Coutinho         Liverpool   27            Midfielder
# 1                Sergio Agüero   Manchester City   31   Midfielder, Forward
# 2      Alex Oxlade Chamberlain           Arsenal   25            Midfielder
# 3              Kevin De Bruyne   Manchester City   28   Midfielder, Forward
# 4                 Henri Saivet  Newcastle United   28   Midfielder, Forward
# ...                        ...               ...  ...                   ...
# 32085            Tammy Abraham           Chelsea   21               Forward
# 32086               Ivan Toney  Newcastle United   23               Forward
# 32087            Hiram Boateng    Crystal Palace   23            Midfielder
# 32088              Adam Bogdan         Liverpool   31                    GK
# 32089         Pedro Chirivella         Liverpool   22  Defender, Midfielder
#
#        Minutes Total Goals Total Assists Yellow cards Red cards  \
# 0         1116           7             6         <NA>      <NA>
# 1         1969          21             6            2      <NA>
# 2          242        <NA>          <NA>         <NA>      <NA>
# 3         3085           8            16            2      <NA>
# 4           84           1          <NA>         <NA>      <NA>
# ...        ...         ...           ...          ...       ...
# 32085       53        <NA>          <NA>         <NA>      <NA>
# 32086       10        <NA>          <NA>         <NA>      <NA>
# 32087       18        <NA>          <NA>         <NA>      <NA>
# 32088      180        <NA>          <NA>         <NA>      <NA>
# 32089       46        <NA>          <NA>         <NA>      <NA>
#
#       Shots per game Pass success percentage Aerials won per game  \
# 0                3.9                    78.8                  0.1
# 1                3.8                    82.8                  0.4
# 2                  3                    84.6                  1.3
# 3                2.5                    83.4                  0.4
# 4                  1                    62.5                    2
# ...              ...                     ...                  ...
# 32085              1                      70                  0.5
# 32086           <NA>                    66.7                 <NA>
# 32087              1                      75                 <NA>
# 32088           <NA>                    46.2                 <NA>
# 32089           <NA>                    72.7                 <NA>
#
#       Man of the match  Rating         League  Saison  Start Application  \
# 0                    6    8.03  PremierLeague    2017                 13
# 1                    4    7.81  PremierLeague    2017                 22
# 2                    1    7.81  PremierLeague    2017                  3
# 3                    8    7.80  PremierLeague    2017                 36
# 4                 <NA>    7.70  PremierLeague    2017                  1
# ...                ...     ...            ...     ...                ...
# 32085             <NA>    5.96  PremierLeague    2015                  0
# 32086             <NA>    5.94  PremierLeague    2015                  0
# 32087             <NA>    5.90  PremierLeague    2015                  0
# 32088             <NA>    5.60  PremierLeague    2015                  2
# 32089             <NA>    5.31  PremierLeague    2015                  1
#
#        Remplacement Application
# 0                             1
# 1                             3
# 2                             0
# 3                             1
# 4                             0
# ...                         ...
# 32085                         2
# 32086                         2
# 32087                         1
# 32088                         0
# 32089                         0
#
# [32090 rows x 18 columns]

# %% [markdown]
# #### Type de données par colonnes

# %%
# Type de données des colonnes de df_defensive
print(df_defensive.dtypes)
# Out:
# Name                         object
# Team                         object
# Age                           int64
# Position                     object
# Minutes                       int64
# Tackles per game             object
# Interceptions per game       object
# Fouls per game               object
# Offsides per game            object
# Clearances per game          object
# Dribbled past per game       object
# Outfield blocks per game     object
# Own goals                    object
# Rating                      float64
# League                       object
# Saison                        int64
# Start Application             int64
# Remplacement Application      int64
# dtype: object

# %%
# Type de données des colonnes de df_summary
print(df_summary.dtypes)
# Out:
# Name                         object
# Team                         object
# Age                           int64
# Position                     object
# Minutes                       int64
# Total Goals                  object
# Total Assists                object
# Yellow cards                 object
# Red cards                    object
# Shots per game               object
# Pass success percentage      object
# Aerials won per game         object
# Man of the match             object
# Rating                      float64
# League                       object
# Saison                        int64
# Start Application             int64
# Remplacement Application      int64
# dtype: object

# %%
# Type de données des colonnes de df_offensive
print(df_offensive.dtypes)
# Out:
# Name                         object
# Team                         object
# Age                           int64
# Position                     object
# Minutes                      object
# Total goals                  object
# Total Assists                object
# Shots per game               object
# Key passes per game          object
# Dribble                     float64
# Fouled per game              object
# Offsides per game            object
# Dispossessed per game        object
# Bad control per game         object
# Rating                      float64
# League                       object
# Saison                        int64
# Dribbles per game            object
# Start Application           float64
# Remplacement Application      int64
# dtype: object

# %%
# Type de données des colonnes de df_passing
print(df_passing.dtypes)
# Out:
# Name                         object
# Team                         object
# Age                           int64
# Position                     object
# Minutes                       int64
# Total Assists                object
# Key passes per game          object
# Passes per game              object
# Pass success percentage      object
# Crosses per game             object
# Long balls per game          object
# Through balls per game       object
# Rating                      float64
# League                       object
# Saison                        int64
# Start Application             int64
# Remplacement Application      int64
# dtype: object

# %% [markdown]
# #### dtype modification

# %%
# liste des colonnes qui doivent être exclues
exclude_cols = ['Name', 'Team', 'Position', 'League']

# boucle à travers toutes les colonnes
for col in df_offensive.columns:
    # vérifier si la colonne doit être convertie en float64
    if col not in exclude_cols and df_offensive[col].dtype == 'object':
        # convertir la colonne en float64
        df_offensive[col] = pd.to_numeric(df_offensive[col], errors='coerce')
        
print(df_offensive.dtypes)
# Out:
# Name                         object
# Team                         object
# Age                           int64
# Position                     object
# Minutes                     float64
# Total goals                 float64
# Total Assists               float64
# Shots per game              float64
# Key passes per game         float64
# Dribble                     float64
# Fouled per game             float64
# Offsides per game           float64
# Dispossessed per game       float64
# Bad control per game        float64
# Rating                      float64
# League                       object
# Saison                        int64
# Dribbles per game           float64
# Start Application           float64
# Remplacement Application      int64
# dtype: object

# %%
# liste des colonnes qui doivent être exclues
exclude_cols = ['Name', 'Team', 'Position', 'League']

# boucle à travers toutes les colonnes
for col in df_defensive.columns:
    # vérifier si la colonne doit être convertie en float64
    if col not in exclude_cols and df_defensive[col].dtype == 'object':
        # convertir la colonne en float64
        df_defensive[col] = pd.to_numeric(df_defensive[col], errors='coerce')
        
print(df_defensive.dtypes)
# Out:
# Name                         object
# Team                         object
# Age                           int64
# Position                     object
# Minutes                       int64
# Tackles per game            float64
# Interceptions per game      float64
# Fouls per game              float64
# Offsides per game           float64
# Clearances per game         float64
# Dribbled past per game      float64
# Outfield blocks per game    float64
# Own goals                   float64
# Rating                      float64
# League                       object
# Saison                        int64
# Start Application             int64
# Remplacement Application      int64
# dtype: object

# %%
# liste des colonnes qui doivent être exclues
exclude_cols = ['Name', 'Team', 'Position', 'League']

# boucle à travers toutes les colonnes
for col in df_passing.columns:
    # vérifier si la colonne doit être convertie en float64
    if col not in exclude_cols and df_passing[col].dtype == 'object':
        # convertir la colonne en float64
        df_passing[col] = pd.to_numeric(df_passing[col], errors='coerce')
        
print(df_passing.dtypes)
# Out:
# Name                         object
# Team                         object
# Age                           int64
# Position                     object
# Minutes                       int64
# Total Assists               float64
# Key passes per game         float64
# Passes per game             float64
# Pass success percentage     float64
# Crosses per game            float64
# Long balls per game         float64
# Through balls per game      float64
# Rating                      float64
# League                       object
# Saison                        int64
# Start Application             int64
# Remplacement Application      int64
# dtype: object

# %%
# liste des colonnes qui doivent être exclues
exclude_cols = ['Name', 'Team', 'Position', 'League']

# boucle à travers toutes les colonnes
for col in df_summary.columns:
    # vérifier si la colonne doit être convertie en float64
    if col not in exclude_cols and df_summary[col].dtype == 'object':
        # convertir la colonne en float64
        df_summary[col] = pd.to_numeric(df_summary[col], errors='coerce')
        
print(df_summary.dtypes)
# Out:
# Name                         object
# Team                         object
# Age                           int64
# Position                     object
# Minutes                       int64
# Total Goals                 float64
# Total Assists               float64
# Yellow cards                float64
# Red cards                   float64
# Shots per game              float64
# Pass success percentage     float64
# Aerials won per game        float64
# Man of the match            float64
# Rating                      float64
# League                       object
# Saison                        int64
# Start Application             int64
# Remplacement Application      int64
# dtype: object

# %% [markdown]
# ### Combined all database

# %%
def merge_dataframes(dataframes):
    """
    Fusionne plusieurs dataframes en utilisant les colonnes qui se retrouvent dans chaque dataframe
    en tant que clés de fusion.

    :param dataframes: une liste de dataframes à fusionner.
    :return: le dataframe fusionné.
    """
    df_merged = dataframes[0]

    for i in range(1, len(dataframes)):
        df_merged = pd.merge(df_merged, dataframes[i], on=list(set(df_merged.columns) & set(dataframes[i].columns)), how="outer")

    return df_merged

# %%
# Fusionner les dataframes
dataframes = [df_offensive, df_defensive, df_summary, df_passing]
df_merged = merge_dataframes(dataframes)

# %%
df_merged
# Out:
#                          Name               Team  Age              Position  \
# 0             Kevin De Bruyne           Man City   31   Midfielder, Forward
# 1               Mohamed Salah          Liverpool   30   Midfielder, Forward
# 2      Trent Alexander-Arnold          Liverpool   24  Defender, Midfielder
# 3               Son Heung-Min          Tottenham   30   Midfielder, Forward
# 4                  Harry Kane          Tottenham   29   Midfielder, Forward
# ...                       ...                ...  ...                   ...
# 63696         Sven Schipplock  Arminia Bielefeld   34               Forward
# 63697       Christian Gebauer  Arminia Bielefeld   29  Defender, Midfielder
# 63698          Hwang Hee-Chan                RBL   27   Midfielder, Forward
# 63699     Sebastian Griesbeck       Union Berlin   32  Defender, Midfielder
# 63700       Alessandro Schöpf            Schalke   29            Midfielder
#
#        Minutes  Total goals  Total Assists  Shots per game  \
# 0          NaN         15.0            8.0             2.6
# 1          NaN         23.0           13.0             4.0
# 2         32.0          2.0           12.0             1.6
# 3         35.0         23.0            7.0             2.5
# 4          NaN         17.0            9.0             3.6
# ...        ...          ...            ...             ...
# 63696    724.0          NaN            0.0             NaN
# 63697    677.0          NaN            1.0             NaN
# 63698    448.0          NaN            1.0             NaN
# 63699    881.0          NaN            0.0             NaN
# 63700    943.0          NaN            0.0             NaN
#
#        Key passes per game  Dribble  ...  Total Goals  Yellow cards  \
# 0                      2.9      1.0  ...          NaN           NaN
# 1                      1.8      1.5  ...          NaN           NaN
# 2                      2.8      0.6  ...          NaN           NaN
# 3                      2.1      1.5  ...          NaN           NaN
# 4                      1.4      1.5  ...          NaN           NaN
# ...                    ...      ...  ...          ...           ...
# 63696                  0.3      NaN  ...          NaN           NaN
# 63697                  0.5      NaN  ...          NaN           NaN
# 63698                  0.2      NaN  ...          NaN           NaN
# 63699                  0.0      NaN  ...          NaN           NaN
# 63700                  0.2      NaN  ...          NaN           NaN
#
#        Red cards  Pass success percentage  Aerials won per game  \
# 0            NaN                      NaN                   NaN
# 1            NaN                      NaN                   NaN
# 2            NaN                      NaN                   NaN
# 3            NaN                      NaN                   NaN
# 4            NaN                      NaN                   NaN
# ...          ...                      ...                   ...
# 63696        NaN                     55.6                   NaN
# 63697        NaN                     67.5                   NaN
# 63698        NaN                     65.8                   NaN
# 63699        NaN                     72.6                   NaN
# 63700        NaN                     81.6                   NaN
#
#       Man of the match  Passes per game  Crosses per game  \
# 0                  NaN              NaN               NaN
# 1                  NaN              NaN               NaN
# 2                  NaN              NaN               NaN
# 3                  NaN              NaN               NaN
# 4                  NaN              NaN               NaN
# ...                ...              ...               ...
# 63696              NaN              5.3               0.0
# 63697              NaN              7.2               0.0
# 63698              NaN              6.7               0.0
# 63699              NaN              9.4               0.0
# 63700              NaN             16.9               0.1
#
#        Long balls per game  Through balls per game
# 0                      NaN                     NaN
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4                      NaN                     NaN
# ...                    ...                     ...
# 63696                  0.1                     0.0
# 63697                  0.5                     0.0
# 63698                  0.2                     0.0
# 63699                  0.3                     0.0
# 63700                  0.2                     0.0
#
# [63701 rows x 37 columns]

# %%
# Liste des valeurs manquantes à remplacer
missing_values = ['', ' ', '-', '--', 'NA', 'N/A', 'n/a', 'NaN', 'nan', '.', '..', '...']

# Remplacer les valeurs manquantes par NaN
df_summary_null = df_merged.replace(missing_values, pd.NA)
# Compter le nombre de valeurs nulles pour chaque colonne
null_counts = df_summary_null.isna().sum()

# Afficher le nombre de valeurs nulles pour chaque colonne
print(null_counts)
# Out:
# Name                            0
# Team                            0
# Age                             0
# Position                        0
# Minutes                      3895
# Total goals                 45899
# Total Assists               36366
# Shots per game              31552
# Key passes per game         31825
# Dribble                     58804
# Fouled per game             34625
# Offsides per game           33510
# Dispossessed per game       36499
# Bad control per game        37886
# Rating                          0
# League                          0
# Saison                          0
# Dribbles per game           42402
# Start Application            4897
# Remplacement Application        0
# Tackles per game            35492
# Interceptions per game      36174
# Fouls per game              35400
# Clearances per game         35270
# Dribbled past per game      36099
# Outfield blocks per game    43249
# Own goals                   57762
# Total Goals                 45897
# Yellow cards                38678
# Red cards                   54989
# Pass success percentage     26231
# Aerials won per game        34602
# Man of the match            49384
# Passes per game             31364
# Crosses per game            43074
# Long balls per game         33811
# Through balls per game      51442
# dtype: int64

# %% [markdown]
# ### Supprimer les lignes qui fossent la prédictions des valeurs

# %%
def drop_rows_with_many_nan(df, threshold):
    # Compter le nombre de NaN par ligne
    nan_count = df.isna().sum(axis=1)
    
    # Sélectionner les lignes qui ont moins de NaN que la limite
    index_to_keep = nan_count[nan_count <= threshold].index
    
    # Retourner le dataframe sans les lignes qui ont trop de NaN
    return df.loc[index_to_keep]

# %%
# Supprimer les lignes avec plus de 16 NaN, choisis car 8 colonnes sont sure d'être écrite.
# On décide de garder 72,2% des colonnes pleines 
df_merged = drop_rows_with_many_nan(df_merged, threshold=16)

# %%
df_merged
# Out:
#                      Name           Team  Age              Position   Apps  \
# 299          Arjen Robben  Bayern Munich   35   Midfielder, Forward  20(1)
# 300       Kevin De Bruyne      Wolfsburg   28   Midfielder, Forward     34
# 301         Franck Ribéry  Bayern Munich   36            Midfielder   9(6)
# 302       Roberto Firmino     Hoffenheim   27   Midfielder, Forward     33
# 303                 Naldo      Wolfsburg   36              Defender     32
# ...                   ...            ...  ...                   ...    ...
# 32144  Kenny Rocha Santos  Saint-Etienne   19            Midfielder   1(2)
# 32148    Dickson Nwakaeme         Angers   33               Forward   0(6)
# 32149        Didier Ndong        Lorient   25  Defender, Midfielder      2
# 32151        Morgan Poaty    Montpellier   21              Defender   1(2)
# 32153       Faiz Selemani        Lorient   25              Defender   0(3)
#
#        Minutes  Total goals  Total Assists  Shots per game  \
# 299     1679.0         17.0            7.0             4.2
# 300     3052.0         10.0           20.0             2.8
# 301      959.0          5.0            7.0             1.5
# 302     2918.0          7.0           10.0             2.9
# 303     2879.0          7.0            2.0             1.6
# ...        ...          ...            ...             ...
# 32144     60.0          NaN            NaN             0.7
# 32148     86.0          NaN            NaN             NaN
# 32149    120.0          NaN            NaN             0.5
# 32151     49.0          NaN            NaN             NaN
# 32153     63.0          NaN            NaN             0.7
#
#        Key passes per game  ...  Total Goals  Yellow cards  Red cards  \
# 299                    2.4  ...         17.0           NaN        NaN
# 300                    3.3  ...         10.0           3.0        NaN
# 301                    1.9  ...          5.0           2.0        NaN
# 302                    2.1  ...          7.0           5.0        NaN
# 303                    0.3  ...          7.0           5.0        NaN
# ...                    ...  ...          ...           ...        ...
# 32144                  NaN  ...          NaN           NaN        NaN
# 32148                  0.3  ...          NaN           1.0        NaN
# 32149                  0.5  ...          NaN           NaN        1.0
# 32151                  NaN  ...          NaN           NaN        1.0
# 32153                  NaN  ...          NaN           2.0        NaN
#
#        Pass success percentage  Aerials won per game  Man of the match  \
# 299                       83.1                   0.9              11.0
# 300                       74.5                   0.5               6.0
# 301                       84.3                   0.4               1.0
# 302                       72.7                   2.3               5.0
# 303                       83.6                   4.8               5.0
# ...                        ...                   ...               ...
# 32144                     56.7                   NaN               NaN
# 32148                     66.7                   0.3               NaN
# 32149                     95.5                   1.5               NaN
# 32151                     77.8                   NaN               NaN
# 32153                     81.0                   0.7               NaN
#
#       Passes per game  Crosses per game  Long balls per game  \
# 299              48.0               0.8                  1.6
# 300              44.7               1.6                  4.5
# 301              55.3               0.5                  2.6
# 302              39.8               0.2                  0.6
# 303              54.0               NaN                  6.1
# ...               ...               ...                  ...
# 32144            10.0               NaN                  0.7
# 32148             3.0               0.2                  0.2
# 32149            33.5               NaN                  1.0
# 32151             3.0               NaN                  NaN
# 32153             7.0               0.3                  NaN
#
#        Through balls per game
# 299                       0.2
# 300                       0.3
# 301                       0.1
# 302                       0.2
# 303                       NaN
# ...                       ...
# 32144                     NaN
# 32148                     NaN
# 32149                     NaN
# 32151                     NaN
# 32153                     NaN
#
# [21691 rows x 36 columns]

# %%
# Liste des valeurs manquantes à remplacer
missing_values = ['', ' ', '-', '--', 'NA', 'N/A', 'n/a', 'NaN', 'nan', '.', '..', '...']

# Remplacer les valeurs manquantes par NaN
df_summary_null = df_merged.replace(missing_values, pd.NA)
# Compter le nombre de valeurs nulles pour chaque colonne
null_counts = df_summary_null.isna().sum()

# Afficher le nombre de valeurs nulles pour chaque colonne
print(null_counts)
# Out:
# Name                            0
# Team                            0
# Age                             0
# Position                        0
# Apps                            0
# Minutes                         0
# Total goals                  5869
# Total Assists                6294
# Shots per game                330
# Key passes per game           377
# Dribble                     18379
# Fouled per game               186
# Offsides per game            7683
# Dispossessed per game         373
# Bad control per game         1825
# Rating                          0
# League                          0
# Saison                          0
# Dribbles per game             757
# Tackles per game            13189
# Interceptions per game      13296
# Fouls per game              13182
# Clearances per game         13440
# Dribbled past per game      13318
# Outfield blocks per game    14800
# Own goals                   18232
# Total Goals                  5868
# Yellow cards                 2292
# Red cards                   15115
# Pass success percentage         0
# Aerials won per game          505
# Man of the match            10074
# Passes per game                 0
# Crosses per game             4367
# Long balls per game           308
# Through balls per game      11307
# dtype: int64

# %%
df_merged = df_merged.loc[:,~df_merged.columns.duplicated()]

# %%
#Removing players who have played less than 10 games in last season
df_merged = df_merged[df_merged['Start Application'] >= 20 ]

# %%
df_merged.describe()
# Out:
#                 Age       Minutes   Total goals  Total Assists  \
# count  41038.000000  41038.000000  10399.000000   19124.000000
# mean      30.372776   1987.623593      4.182325       2.486405
# std        4.966730    669.999160      4.447708       2.399313
# min       18.000000    654.000000      1.000000       0.000000
# 25%       27.000000   1430.000000      1.000000       1.000000
# 50%       30.000000   1944.500000      3.000000       2.000000
# 75%       34.000000   2520.000000      5.000000       3.000000
# max       49.000000   3420.000000     50.000000      20.000000
#
#        Shots per game  Key passes per game  Dribble  Fouled per game  \
# count    19150.000000         19313.000000      0.0     16034.000000
# mean         1.001922             0.747419      NaN         1.000854
# std          0.795783             0.558210      NaN         0.606361
# min          0.000000             0.000000      NaN         0.100000
# 25%          0.400000             0.300000      NaN         0.600000
# 50%          0.800000             0.600000      NaN         0.900000
# 75%          1.400000             1.000000      NaN         1.300000
# max          7.400000             4.200000      NaN         5.500000
#
#        Offsides per game  Dispossessed per game  ...   Total Goals  \
# count       19125.000000           14609.000000  ...  14741.000000
# mean            0.331702               0.940694  ...      3.794722
# std             0.336939               0.667178  ...      4.352566
# min             0.000000               0.100000  ...      0.000000
# 25%             0.100000               0.400000  ...      1.000000
# 50%             0.200000               0.800000  ...      2.000000
# 75%             0.500000               1.300000  ...      5.000000
# max             2.600000               5.300000  ...     50.000000
#
#        Yellow cards    Red cards  Pass success percentage  \
# count  19424.000000  7554.000000             24940.000000
# mean       4.114858     0.567646                77.486179
# std        2.685038     0.620913                 8.950273
# min        0.000000     0.000000                27.400000
# 25%        2.000000     0.000000                73.300000
# 50%        4.000000     1.000000                78.900000
# 75%        6.000000     1.000000                83.600000
# max       18.000000     5.000000                96.100000
#
#        Aerials won per game  Man of the match  Passes per game  \
# count          20258.000000      12969.000000     20527.000000
# mean               1.216956          1.705220        33.411838
# std                1.016299          1.648566        13.445455
# min                0.000000          0.000000         5.500000
# 25%                0.500000          1.000000        23.900000
# 50%                0.900000          1.000000        31.600000
# 75%                1.700000          2.000000        41.100000
# max                9.300000         25.000000       110.000000
#
#        Crosses per game  Long balls per game  Through balls per game
# count      15520.000000         20489.000000            10100.000000
# mean           0.451282             2.419611                0.106941
# std            0.464129             2.155439                0.120213
# min            0.000000             0.000000                0.000000
# 25%            0.100000             0.900000                0.000000
# 50%            0.300000             1.800000                0.100000
# 75%            0.600000             3.200000                0.100000
# max            3.900000            19.000000                1.500000
#
# [8 rows x 33 columns]

# %%
def fill_missing_values(df):
    """
    Remplit les valeurs manquantes d'un DataFrame en utilisant la méthode des moindres carrés pour estimer les coefficients d'influence de chaque colonne sur les autres.
    
    Arguments:
    - df: DataFrame avec des colonnes contenant des valeurs manquantes
    
    Returns:
    - DataFrame avec les valeurs manquantes remplies
    """
    # Parcourt chaque colonne du DataFrame
    for column in df.columns:
        # Vérifie si la colonne contient des valeurs manquantes
        if df[column].isnull().sum() > 0:
            # Crée une copie du DataFrame sans la colonne en cours de traitement
            X = df.drop(columns=[column])
            # Supprime toutes les lignes avec des valeurs manquantes
            X = X.dropna()
            # Crée un tableau avec les valeurs de la colonne en cours de traitement, sans les valeurs manquantes
            y = X[[column]].values.reshape(-1, 1)
            # Supprime la colonne en cours de traitement du DataFrame original
            X_test = df.drop(columns=[column])
            # Crée un tableau avec les valeurs de la colonne en cours de traitement à remplir, sans les valeurs manquantes
            y_test = X_test[column].dropna().values.reshape(-1, 1)
            # Supprime les lignes correspondantes dans le DataFrame original
            X_test = X_test.dropna()
            # Crée un modèle de régression linéaire
            model = LinearRegression()
            # Entraîne le modèle sur les données sans les valeurs manquantes
            model.fit(X, y)
            # Estime les coefficients d'influence de chaque colonne sur la colonne en cours de traitement
            coefficients = model.coef_.flatten()
            # Remplit les valeurs manquantes en utilisant la méthode des moindres carrés
            for i, row in X_test.iterrows():
                if np.isnan(df.loc[i, column]):
                    values = row.values
                    values = np.delete(values, np.argwhere(np.isnan(values)))
                    prediction = np.dot(values, coefficients)
                    df.loc[i, column] = prediction
    return df

# %%
df_filled = fill_missing_values(df_merged)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_93404\900071428.py in <module>
# ----> 1 df_filled = fill_missing_values(df_merged)
#
# ~\AppData\Local\Temp\ipykernel_93404\1220890825.py in fill_missing_values(df)
#      18             X = X.dropna()
#      19             # Crée un tableau avec les valeurs de la colonne en cours de traitement, sans les valeurs manquantes
# ---> 20             y = X[[column]].values.reshape(-1, 1)
#      21             # Supprime la colonne en cours de traitement du DataFrame original
#      22             X_test = df.drop(columns=[column])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5854                 if use_interval_msg:
#    5855                     key = list(key)
# -> 5856                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Total goals'], dtype='object')] are in the [columns]"

# %%
# Supprimer la colonne "Own goals" car trop de valeurs vides
df_merged = df_merged.drop("Own goals", axis=1)
